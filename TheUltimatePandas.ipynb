# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Series

# %%
mydata = ["Etsy", "Amazon", "Ikas", "Trendyol"]
mySeries= pd.Series(mydata)

# %%
mySeries
# Out:
# 0        Etsy
# 1      Amazon
# 2        Ikas
# 3    Trendyol
# dtype: object

# %%
data = [16, 41, 234, 65]
mySeries1=pd.Series(data)

# %%
mySeries1
# Out:
# 0     16
# 1     41
# 2    234
# 3     65
# dtype: int64

# %% [markdown]
# # DataFrame

# %%
df = [("Etsy", 18),("Amazon",0),("Ikas", 121),("Trendyol",233)]
mydf=pd.DataFrame(df, columns=["market","sales"])

# %%
mydf
# Out:
#      market  sales
# 0      Etsy     18
# 1    Amazon      0
# 2      Ikas    121
# 3  Trendyol    233

# %%
mydf.dtypes
# Out:
# market    object
# sales      int64
# dtype: object

# %% [markdown]
# # Reading in Data

# %%
dataF = pd.read_excel("starwars.xlsx")

# %%
dataF.head()
# Out:
#              name  height   mass hair_color   skin_color eye_color  \
# 0  Luke Skywalker   172.0   77.0      blond         fair      blue
# 1           C-3PO   167.0    NaN        NaN         gold    yellow
# 2             NaN     NaN    NaN        NaN          NaN       NaN
# 3           R2-D2    96.0   32.0        NaN  white, blue       red
# 4     Darth Vader   202.0  136.0       none        white    yellow
#
#    birth_year   sex homeworld species
# 0        19.0  male  Tatooine   Human
# 1       112.0  none  Tatooine   Droid
# 2         NaN   NaN       NaN     NaN
# 3        33.0  none     Naboo   Droid
# 4        41.9  male  Tatooine   Human

# %%
dataF.tail()
# Out:
#              name  height  mass hair_color skin_color eye_color  birth_year  \
# 18           Finn     NaN   NaN        NaN        NaN       NaN         NaN
# 19            Rey     NaN   NaN      brown      light     hazel         NaN
# 20    Poe Dameron     NaN   NaN        NaN        NaN       NaN         NaN
# 21            BB8     NaN   NaN       none       none       NaN         NaN
# 22  Padmé Amidala   165.0  45.0      brown      light     brown        46.0
#
#        sex homeworld species
# 18     NaN       NaN     NaN
# 19  female       NaN   Human
# 20     NaN       NaN   Human
# 21    none       NaN   Droid
# 22  female     Naboo   Human

# %%
dataF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        21 non-null     object
#  1   height      14 non-null     float64
#  2   mass        13 non-null     float64
#  3   hair_color  14 non-null     object
#  4   skin_color  13 non-null     object
#  5   eye_color   12 non-null     object
#  6   birth_year  13 non-null     float64
#  7   sex         17 non-null     object
#  8   homeworld   12 non-null     object
#  9   species     20 non-null     object
# dtypes: float64(3), object(7)
# memory usage: 1.9+ KB

# %%
dataF.dtypes
# Out:
# name           object
# height        float64
# mass          float64
# hair_color     object
# skin_color     object
# eye_color      object
# birth_year    float64
# sex            object
# homeworld      object
# species        object
# dtype: object

# %%
dataF.describe()
# Out:
#            height        mass  birth_year
# count   14.000000   13.000000   13.000000
# mean   172.714286   77.461538  129.907692
# std     43.285152   38.621271  235.649476
# min     66.000000   17.000000   19.000000
# 25%    167.750000   49.000000   33.000000
# 50%    181.000000   80.000000   46.000000
# 75%    193.000000   84.000000  102.000000
# max    228.000000  159.000000  896.000000

# %% [markdown]
# # Columns and Rows

# %%
dataF.head()
# Out:
#              name  height   mass hair_color   skin_color eye_color  \
# 0  Luke Skywalker   172.0   77.0      blond         fair      blue
# 1           C-3PO   167.0    NaN        NaN         gold    yellow
# 2             NaN     NaN    NaN        NaN          NaN       NaN
# 3           R2-D2    96.0   32.0        NaN  white, blue       red
# 4     Darth Vader   202.0  136.0       none        white    yellow
#
#    birth_year   sex homeworld species
# 0        19.0  male  Tatooine   Human
# 1       112.0  none  Tatooine   Droid
# 2         NaN   NaN       NaN     NaN
# 3        33.0  none     Naboo   Droid
# 4        41.9  male  Tatooine   Human

# %%
dataF["height"]
# Out:
# 0     172.0
# 1     167.0
# 2       NaN
# 3      96.0
# 4     202.0
# 5       NaN
# 6     182.0
# 7     188.0
# 8     228.0
# 9      66.0
# 10      NaN
# 11    170.0
# 12      NaN
# 13    180.0
# 14    193.0
# 15      NaN
# 16    193.0
# 17    216.0
# 18      NaN
# 19      NaN
# 20      NaN
# 21      NaN
# 22    165.0
# Name: height, dtype: float64

# %%
dataF.loc[3]
# Out:
# name                R2-D2
# height               96.0
# mass                 32.0
# hair_color            NaN
# skin_color    white, blue
# eye_color             red
# birth_year           33.0
# sex                  none
# homeworld           Naboo
# species             Droid
# Name: 3, dtype: object

# %%
dataF=dataF.set_index("name")

# %%
dataF.loc["R2-D2"]
# Out:
# height               96.0
# mass                 32.0
# hair_color            NaN
# skin_color    white, blue
# eye_color             red
# birth_year           33.0
# sex                  none
# homeworld           Naboo
# species             Droid
# Name: R2-D2, dtype: object

# %% [markdown]
# # Subsetting Data

# %%
dataF
# Out:
#                   height   mass hair_color   skin_color eye_color  birth_year  \
# name
# Luke Skywalker     172.0   77.0      blond         fair      blue        19.0
# C-3PO              167.0    NaN        NaN         gold    yellow       112.0
# NaN                  NaN    NaN        NaN          NaN       NaN         NaN
# R2-D2               96.0   32.0        NaN  white, blue       red        33.0
# Darth Vader        202.0  136.0       none        white    yellow        41.9
# Leia Organa          NaN   49.0      brown          NaN       NaN        19.0
# Obi-Wan Kenobi     182.0   84.0     auburn         fair      grey        57.0
# Anakin Skywalker   188.0   84.0      blond         fair      blue        41.9
# Chewbacca          228.0    NaN      brown          NaN       NaN       200.0
# Yoda                66.0   17.0       grey         pale    yellow       896.0
# NaN                  NaN    NaN        NaN          NaN       NaN         NaN
# ...

# %%
dataF.columns
# Out:
# Index(['height', 'mass', 'hair_color', 'skin_color', 'eye_color', 'birth_year',
#        'sex', 'homeworld', 'species'],
#       dtype='object')

# %%
#Subsettşng Columns
dataF[["height","mass","species"]]
# Out:
#                   height   mass         species
# name
# Luke Skywalker     172.0   77.0           Human
# C-3PO              167.0    NaN           Droid
# NaN                  NaN    NaN             NaN
# R2-D2               96.0   32.0           Droid
# Darth Vader        202.0  136.0           Human
# Leia Organa          NaN   49.0           Human
# Obi-Wan Kenobi     182.0   84.0           Human
# Anakin Skywalker   188.0   84.0           Human
# Chewbacca          228.0    NaN             NaN
# Yoda                66.0   17.0  Yoda's species
# NaN                  NaN    NaN           Droid
# Palpatine          170.0   75.0           Human
# Boba Fett            NaN    NaN           Human
# Han Solo           180.0   80.0           Human
# Qui-Gon Jinn       193.0   89.0           Human
# Darth Maul           NaN    NaN          Zabrak
# Dooku              193.0   80.0           Human
# Grievous           216.0  159.0         Kaleesh
# ...

# %%
dataF.head()
# Out:
#                 height   mass hair_color   skin_color eye_color  birth_year  \
# name
# Luke Skywalker   172.0   77.0      blond         fair      blue        19.0
# C-3PO            167.0    NaN        NaN         gold    yellow       112.0
# NaN                NaN    NaN        NaN          NaN       NaN         NaN
# R2-D2             96.0   32.0        NaN  white, blue       red        33.0
# Darth Vader      202.0  136.0       none        white    yellow        41.9
#
#                  sex homeworld species
# name
# Luke Skywalker  male  Tatooine   Human
# C-3PO           none  Tatooine   Droid
# NaN              NaN       NaN     NaN
# R2-D2           none     Naboo   Droid
# Darth Vader     male  Tatooine   Human

# %%
dataF.shape
# Out:
# (23, 9)

# %%
#Subsetting Rows

# %%
dataF.loc[dataF["height"] >150]
# Out:
#                   height   mass hair_color skin_color eye_color  birth_year  \
# name
# Luke Skywalker     172.0   77.0      blond       fair      blue        19.0
# C-3PO              167.0    NaN        NaN       gold    yellow       112.0
# Darth Vader        202.0  136.0       none      white    yellow        41.9
# Obi-Wan Kenobi     182.0   84.0     auburn       fair      grey        57.0
# Anakin Skywalker   188.0   84.0      blond       fair      blue        41.9
# Chewbacca          228.0    NaN      brown        NaN       NaN       200.0
# Palpatine          170.0   75.0        NaN        NaN       NaN         NaN
# Han Solo           180.0   80.0      brown        NaN     brown        29.0
# Qui-Gon Jinn       193.0   89.0        NaN       fair       NaN        92.0
# Dooku              193.0   80.0      white       fair     brown       102.0
# Grievous           216.0  159.0       none        NaN       NaN         NaN
# ...

# %%
dataF.query("height > 150")
# Out:
#                   height   mass hair_color skin_color eye_color  birth_year  \
# name
# Luke Skywalker     172.0   77.0      blond       fair      blue        19.0
# C-3PO              167.0    NaN        NaN       gold    yellow       112.0
# Darth Vader        202.0  136.0       none      white    yellow        41.9
# Obi-Wan Kenobi     182.0   84.0     auburn       fair      grey        57.0
# Anakin Skywalker   188.0   84.0      blond       fair      blue        41.9
# Chewbacca          228.0    NaN      brown        NaN       NaN       200.0
# Palpatine          170.0   75.0        NaN        NaN       NaN         NaN
# Han Solo           180.0   80.0      brown        NaN     brown        29.0
# Qui-Gon Jinn       193.0   89.0        NaN       fair       NaN        92.0
# Dooku              193.0   80.0      white       fair     brown       102.0
# Grievous           216.0  159.0       none        NaN       NaN         NaN
# ...

# %%
dataF.loc[dataF["species"].isna()]
# Out:
#            height  mass hair_color skin_color eye_color  birth_year  sex  \
# name
# NaN           NaN   NaN        NaN        NaN       NaN         NaN  NaN
# Chewbacca   228.0   NaN      brown        NaN       NaN       200.0  NaN
# Finn          NaN   NaN        NaN        NaN       NaN         NaN  NaN
#
#           homeworld species
# name
# NaN             NaN     NaN
# Chewbacca       NaN     NaN
# Finn            NaN     NaN

# %% [markdown]
# # Casting dtypes

# %%
dataF.dtypes
# Out:
# height        float64
# mass          float64
# hair_color     object
# skin_color     object
# eye_color      object
# birth_year    float64
# sex            object
# homeworld      object
# species        object
# dtype: object

# %%
dataF["height"]
# Out:
# name
# Luke Skywalker      172.0
# C-3PO               167.0
# NaN                   NaN
# R2-D2                96.0
# Darth Vader         202.0
# Leia Organa           NaN
# Obi-Wan Kenobi      182.0
# Anakin Skywalker    188.0
# Chewbacca           228.0
# Yoda                 66.0
# NaN                   NaN
# Palpatine           170.0
# Boba Fett             NaN
# Han Solo            180.0
# Qui-Gon Jinn        193.0
# Darth Maul            NaN
# Dooku               193.0
# Grievous            216.0
# Finn                  NaN
# Rey                   NaN
# Poe Dameron           NaN
# BB8                   NaN
# Padmé Amidala       165.0
# Name: height, dtype: float64

# %%
mean_height = dataF["height"].mean()
dataF["height"] = dataF["height"].fillna(mean_height).astype(int)

# %%
dataF["height"]
# Out:
# name
# Luke Skywalker      172
# C-3PO               167
# NaN                 172
# R2-D2                96
# Darth Vader         202
# Leia Organa         172
# Obi-Wan Kenobi      182
# Anakin Skywalker    188
# Chewbacca           228
# Yoda                 66
# NaN                 172
# Palpatine           170
# Boba Fett           172
# Han Solo            180
# Qui-Gon Jinn        193
# Darth Maul          172
# Dooku               193
# Grievous            216
# Finn                172
# Rey                 172
# Poe Dameron         172
# BB8                 172
# Padmé Amidala       165
# Name: height, dtype: int32

# %% [markdown]
# # Creating new column

# %%
dataF.head()
# Out:
#                 height   mass hair_color   skin_color eye_color  birth_year  \
# name
# Luke Skywalker     172   77.0      blond         fair      blue        19.0
# C-3PO              167    NaN        NaN         gold    yellow       112.0
# NaN                172    NaN        NaN          NaN       NaN         NaN
# R2-D2               96   32.0        NaN  white, blue       red        33.0
# Darth Vader        202  136.0       none        white    yellow        41.9
#
#                  sex homeworld species
# name
# Luke Skywalker  male  Tatooine   Human
# C-3PO           none  Tatooine   Droid
# NaN              NaN       NaN     NaN
# R2-D2           none     Naboo   Droid
# Darth Vader     male  Tatooine   Human

# %%
dataF["height+mass"] = dataF["height"] + dataF["mass"]

# %%
dataF.head()
# Out:
#                 height   mass hair_color   skin_color eye_color  birth_year  \
# name
# Luke Skywalker     172   77.0      blond         fair      blue        19.0
# C-3PO              167    NaN        NaN         gold    yellow       112.0
# NaN                172    NaN        NaN          NaN       NaN         NaN
# R2-D2               96   32.0        NaN  white, blue       red        33.0
# Darth Vader        202  136.0       none        white    yellow        41.9
#
#                  sex homeworld species  height+mass
# name
# Luke Skywalker  male  Tatooine   Human        249.0
# C-3PO           none  Tatooine   Droid          NaN
# NaN              NaN       NaN     NaN          NaN
# R2-D2           none     Naboo   Droid        128.0
# Darth Vader     male  Tatooine   Human        338.0

# %% [markdown]
# # Plot Examples

# %%
dataF["height"].plot(kind="hist", bins=10,
                     title="Distribution of Height",
                     figsize=(15,5))
# Out:
# <Axes: title={'center': 'Distribution of Height'}, ylabel='Frequency'>

# %%
dataF.plot(kind="scatter", x="mass", y="height",
           title="Mass vs Height")
# Out:
# <Axes: title={'center': 'Mass vs Height'}, xlabel='mass', ylabel='height'>

# %%
dataF.query("height > 200")
# Out:
#              height   mass hair_color skin_color eye_color  birth_year   sex  \
# name
# Darth Vader     202  136.0       none      white    yellow        41.9  male
# Chewbacca       228    NaN      brown        NaN       NaN       200.0   NaN
# Grievous        216  159.0       none        NaN       NaN         NaN  male
#
#             homeworld  species  height+mass
# name
# Darth Vader  Tatooine    Human        338.0
# Chewbacca         NaN      NaN          NaN
# Grievous        Kalee  Kaleesh        375.0
